# %%
import pandas as pd

property = pd.read_csv("../data/datasets/property.csv")
rent = pd.read_csv("../data/datasets/rent.csv")

# Filtering only "New York"
property_ny = property[property["State"]=="NY"]
rent_ny = rent[rent["State"]=="NY"]

print(property_ny.head)
print(rent_ny.shape)
# Out:
# <bound method NDFrame.head of        RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 3         62080         4       11368        zip        NY    NY     New York
# 6         62093         7       11385        zip        NY    NY     New York
# 8         62019         9       11208        zip        NY    NY     New York
# 15        62046        16       11236        zip        NY    NY     New York
# 16        61807        17       10467        zip        NY    NY     New York
# ...         ...       ...         ...        ...       ...   ...          ...
# 26259     63100     39992       13410        zip        NY    NY    Nelliston
# 26268     63588     39992       14537        zip        NY    NY  Port Gibson
# 26275     62754     39992       12791        zip        NY    NY  Youngsville
# 26282     62755     39992       12792        zip        NY    NY        Yulan
# 26296     63115     39992       13435        zip        NY    NY     Prospect
#
#                                        Metro         CountyName  \
# 3      New York-Newark-Jersey City, NY-NJ-PA      Queens County
# 6      New York-Newark-Jersey City, NY-NJ-PA      Queens County
# 8      New York-Newark-Jersey City, NY-NJ-PA       Kings County
# 15     New York-Newark-Jersey City, NY-NJ-PA       Kings County
# 16     New York-Newark-Jersey City, NY-NJ-PA       Bronx County
# ...                                      ...                ...
# 26259                          Amsterdam, NY  Montgomery County
# 26268                          Rochester, NY     Ontario County
# 26275                                    NaN    Sullivan County
# 26282                                    NaN    Sullivan County
# 26296                         Utica-Rome, NY      Oneida County
#
#           2000-01-31  ...     2025-04-30     2025-05-31     2025-06-30  \
# 3      172864.490023  ...  528122.229315  528512.439633  530570.039974
# 6      266510.904024  ...  834624.656500  837651.566858  841223.090812
# 8      185811.961563  ...  694662.817198  697000.110905  699994.550100
# 15     191041.148394  ...  660351.747087  663231.481692  666133.275666
# 16     166177.296667  ...  394023.104229  395482.915993  399020.568446
# ...              ...  ...            ...            ...            ...
# 26259   28345.580012  ...  136767.134845  138180.127913  138631.709327
# 26268            NaN  ...  174448.393142  175976.194988  178422.967712
# 26275   75360.545360  ...  267904.149197  268170.464342  267241.299333
# 26282   78029.728180  ...  313494.765600  312962.561620  311637.667100
# 26296            NaN  ...  169435.761489  168853.655393  169736.344179
#
#           2025-07-31     2025-08-31     2025-09-30     2025-10-31  \
# 3      533309.674869  534970.696579  536204.071877  537227.467900
# 6      843314.782197  844395.151600  846666.343231  849999.615624
# 8      701824.877957  703090.386797  705099.650955  707669.063740
# 15     668315.227600  669779.922500  670988.277758  672877.655270
# 16     403547.495120  407635.552000  411572.433148  415139.141868
# ...              ...            ...            ...            ...
# 26259  138469.085790  137610.453330  137033.097782  136184.326410
# 26268  181089.753965  183066.707949  183573.848196  182884.815273
# 26275  265597.532897  264165.791675  263759.357337  263158.193144
# 26282  309737.741508  308818.686400  308757.577857  309052.293608
# 26296  171707.547541  173977.160080  175199.081236  174480.777489
#
#           2025-11-30     2025-12-31     2026-01-31
# 3      539139.357023  541823.178015  546584.297400
# 6      852627.705781  854413.615447  856215.490900
# 8      711720.775790  716180.599902  721653.974000
# 15     674853.978918  677658.864807  680664.857062
# 16     417986.003096  417725.171000  420108.546600
# ...              ...            ...            ...
# 26259  135495.308173  134993.642118  135324.648065
# 26268  182061.616186  181746.405914  181828.045017
# 26275  263672.218141  264083.605462  266596.133408
# 26282  310048.819739  310010.467419  309312.752508
# 26296  171863.081971  168885.467010  167336.648019
#
# [1561 rows x 322 columns]>
# (388, 142)

# %%
# clean the dataset [zip, price], [zip, rent]
latest_price = property_ny.columns[-1]
latest_rent = rent_ny.columns[-1]

property_clean = property_ny[["RegionName", latest_price]]
rent_clean = rent_ny[["RegionName", latest_rent]]

property_clean.columns = ["zip", "price"]
rent_clean.columns = ["zip", "rent"]

# %%
# merge two dataset by zip
df = pd.merge(property_clean, rent_clean, on='zip')
# change data type of zip from float to str
df["zip"] = df["zip"].astype(str)
df

# %%
# calcualte ROI
df["ROI"] = (df["rent"]*12) / df["price"]
df

# %%
income = pd.read_csv("../data/datasets/income.csv")

# Clear median income data [zip, median_income]
income = income.iloc[1:]
income = income[["NAME", "B19013_001E"]]
income.columns = ["zip", "median_income"]
income["zip"] = income["zip"].str[-5:]
income_ny = income[income["zip"].isin(df["zip"])]

income

# %%
# [zip, price, rent, ROI, median_price]
investment_df = pd.merge(df, income, on="zip", how="left")
investment_df

# %%
# highest income
investment_df.sort_values("median_income", ascending=False).head()

# %%
# highest ROI
investment_df.sort_values("ROI", ascending=False).head()

# %%
# Relation ROI vs income
investment_df.plot.scatter(x="median_income", y="ROI")
investment_df.dtypes

# %%
investment_df["median_income"] = pd.to_numeric(investment_df["median_income"])
investment_df[
    (investment_df["ROI"] > 0.08) &
    (investment_df["median_income"] > 50000)
].sort_values("ROI", ascending=False)

# %%
mortgage_rate = 0.065
investment_df["annual_mortgage_interest_cost"] = investment_df["price"]*mortgage_rate
investment_df[["zip","price","annual_mortgage_interest_cost"]].head()

# %%
investment_df["cash_flow"] = (
    investment_df['rent']*12
  - investment_df["annual_mortgage_interest_cost"]
)
investment_df[["zip","annual_mortgage_interest_cost","cash_flow"]].head()

# %%
investment_df["ROI_after_interest"] = (
    investment_df["cash_flow"] / investment_df["price"]
)

investment_df[["zip","ROI","ROI_after_interest"]].head()

# %%
def z(s):
    return (s - s.mean()) / s.std(ddof=0)

# Standardized column
investment_df["z_roi_ai"] = z(investment_df["ROI_after_interest"])
investment_df["z_income"] = z(investment_df["median_income"])
investment_df["z_price"]  = z(investment_df["price"])

# 3) Investment Score (가중치: ROI 0.5, Income 0.3, Price(낮을수록 좋음) 0.2)
investment_df["investment_score"] = (
    0.5 * investment_df["z_roi_ai"]
    + 0.3 * investment_df["z_income"]
    - 0.2 * investment_df["z_price"]
)

investment_df[["zip","ROI_after_interest","median_income","price","investment_score"]].head()

# %%
top10 = investment_df.sort_values(
    "investment_score", ascending=False
).head(10)

top10[["zip","price","rent","ROI_after_interest","median_income","investment_score"]]

# %%
investment_df.plot.scatter(
    x="median_income",
    y="investment_score"
)

# %%
newyork_df = investment_df
